# %% [markdown]
# # 项目：可视化帕默群岛企鹅数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析报告的目的是对帕默群岛上企鹅样本的相关变量进行可视化，从而探索和分析种类、性别、所在岛屿等因素，与企鹅的身体属性，包括体重、嘴峰长度和深度、鳍的长度，之间的关系。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据`Penguins.csv`包括334个收集自南极洲帕尔默群岛的3个岛屿上的企鹅样本，以及企鹅相关属性数据，包括种类名、所在岛、嘴峰长度、嘴峰深度、鳍长度、体重、性别。
#
# `Penguins.csv`每列的含义如下：
# - species：企鹅的种类
# - island：企鹅所在岛
# - culmen_length_mm：企鹅嘴峰的长度（单位为毫米）
# - culmen_depth_mm：企鹅嘴峰的深度（单位为毫米）
# - flipper_length_mm：企鹅鳍的长度（单位为毫米）
# - body_mass_g：企鹅体重（单位为克）
# - sex：企鹅性别

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
penguins=pd.read_csv(r"F:\数据分析\数据可视化\penguins.csv")
penguins
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins[penguins['sex'].isnull()]
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 8    Adelie  Torgersen              34.1             18.1              193.0
# 9    Adelie  Torgersen              42.0             20.2              190.0
# 10   Adelie  Torgersen              37.8             17.1              186.0
# 11   Adelie  Torgersen              37.8             17.3              180.0
# 47   Adelie      Dream              37.5             18.9              179.0
# 246  Gentoo     Biscoe              44.5             14.3              216.0
# 286  Gentoo     Biscoe              46.2             14.4              214.0
# 324  Gentoo     Biscoe              47.3             13.8              216.0
# 339  Gentoo     Biscoe               NaN              NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 47        2975.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN
# 339          NaN  NaN

# %%
penguins.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
penguins.duplicated().sum()
# Out:
# np.int64(0)

# %%
cleaned_penguins=penguins.copy()
cleaned_penguins
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
cleaned_penguins=cleaned_penguins.drop(3)

# %%
cleaned_penguins=cleaned_penguins.drop(339)

# %%
cleaned_penguins
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [342 rows x 7 columns]

# %%
cleaned_penguins = cleaned_penguins.reset_index(drop=True)

# %%
cleaned_penguins
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen              36.7             19.3              193.0
# 4    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 337  Gentoo     Biscoe              47.2             13.7              214.0
# 338  Gentoo     Biscoe              46.8             14.3              215.0
# 339  Gentoo     Biscoe              50.4             15.7              222.0
# 340  Gentoo     Biscoe              45.2             14.8              212.0
# 341  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3         3450.0  FEMALE
# 4         3650.0    MALE
# ..           ...     ...
# 337       4925.0  FEMALE
# 338       4850.0  FEMALE
# 339       5750.0    MALE
# 340       5200.0  FEMALE
# 341       5400.0    MALE
#
# [342 rows x 7 columns]

# %%
cleaned_penguins['species'] = cleaned_penguins['species'].astype("category")
cleaned_penguins['sex'] = cleaned_penguins['sex'].astype("category")
cleaned_penguins['island'] = cleaned_penguins['island'].astype("category")

# %%
cleaned_penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            342 non-null    category
#  1   island             342 non-null    category
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    category
# dtypes: category(3), float64(4)
# memory usage: 12.2 KB

# %%
cleaned_penguins['species'].value_counts()
# Out:
# species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %%
cleaned_penguins['island'].value_counts()
# Out:
# island
# Biscoe       167
# Dream        124
# Torgersen     51
# Name: count, dtype: int64

# %%
cleaned_penguins['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %%
cleaned_penguins['sex'] = cleaned_penguins['sex'].replace(".", np.nan)
# Out:
# C:\Users\杨泽翔\AppData\Local\Temp\ipykernel_6844\661166922.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   cleaned_penguins['sex'] = cleaned_penguins['sex'].replace(".", np.nan)

# %%
cleaned_penguins['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %% [markdown]
# ### 企鹅种类比例

# %%
count_species=cleaned_penguins['species'].value_counts()
plt.pie(count_species,autopct='%.1f%%',labels=count_species.index)
plt.show()

# %% [markdown]
# ### 企鹅所属岛屿比例

# %%
count_island=cleaned_penguins['island'].value_counts()
plt.pie(count_island,autopct='%.1f%%',labels=count_island.index)
plt.show()

# %% [markdown]
# ### 企鹅性别比例

# %%
count_sex = cleaned_penguins['sex'].value_counts()
plt.pie(count_sex, labels=count_sex.index, autopct='%.1f%%')
plt.show()

# %% [markdown]
# ### 不同岛上的企鹅种类数量

# %%
sns.countplot(cleaned_penguins,x='island',hue='species')
plt.show()

# %%
sns.countplot(cleaned_penguins,x='island',hue='sex')
plt.show()

# %%
sns.countplot(cleaned_penguins,x='species',hue='sex')
plt.show()

# %%
sns.pairplot(cleaned_penguins)
plt.show()

# %%
sns.pairplot(cleaned_penguins,hue='species')
plt.show()

# %%
sns.pairplot(cleaned_penguins,hue='species',kind='reg',plot_kws={'scatter_kws':{'alpha':0.3}})
plt.show()

# %% [markdown]
# ### 成正相关

# %%
sns.pairplot(cleaned_penguins,hue='sex')
plt.show()

# %% [markdown]
# ### 雄性普遍高于雌性
